# %%
import requests
import json
import random
import time
import pandas as pd
import threading
from oauth2client.service_account import ServiceAccountCredentials
from google.oauth2.service_account import Credentials
import gspread
import pytz
from datetime import datetime

# %%
def random_delay(min_ms, max_ms):
    delay = (min_ms + (max_ms - min_ms) * random.random()) / 1000.0
    time.sleep(delay)

# %%
creds_dict = {
    "type": "service_account",
    "project_id": "aynma-445820",
    "private_key_id": "17e461e240c2a74164b7926d48fae627df4955e9",
    "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
    "client_email": "aynma-356@aynma-445820.iam.gserviceaccount.com",
    "client_id": "107363630163449145902",
    "auth_uri": "https://accounts.google.com/o/oauth2/auth",
    "token_uri": "https://oauth2.googleapis.com/token",
    "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
    "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/aynma-356%40aynma-445820.iam.gserviceaccount.com",
    "universe_domain": "googleapis.com"
}
scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
spreadsheet_id = '10fb_--c3W9qYw2Eky6pFCexOpdm221gthHvg_Qevah8'
credentials = ServiceAccountCredentials.from_json_keyfile_dict(creds_dict, scope)
client = gspread.authorize(credentials)
spreadsheet = client.open_by_key(spreadsheet_id)
sheet_name = 'aynma'
sheet = client.open(sheet_name).sheet1
data = sheet.get_all_records()
df = pd.DataFrame(data)
df.head()
# Out:
#           No. النوع                                    أسم المنتج  \
# 0  1160462380  منتج        نارس أحمر شفاه أفتر جلو شاين - اورقازم
# 1  1800282403  منتج         نارس أحمر شفاه أفتر جلو شاين - فولتاج
# 2   425787938  منتج                  مسكرا نارس كليماكس ميني NARS
# 3  2109719584  منتج  نارس كريم أساس طبيعي طويل الأمد-فانواتو-30مل
# 4   601007399  منتج    نارس كريم أساس طبيعي طويل الأمد-أروبا-30مل
#
#   رمز المنتج sku سعر المنتج سعر التكلفة السعر المخفض تاريخ نهاية التخفيض
# 0   194251133683     155.25
# 1   194251133713     155.25
# 2   607845270102       89.7
# 3   607845066149        253                      167
# 4   607845066170        253                      167

# %%
df.drop(['النوع', 'سعر التكلفة', 'تاريخ نهاية التخفيض'], axis=1, inplace=True)
df.head()
# Out:
#           No.                                    أسم المنتج رمز المنتج sku  \
# 0  1160462380        نارس أحمر شفاه أفتر جلو شاين - اورقازم   194251133683
# 1  1800282403         نارس أحمر شفاه أفتر جلو شاين - فولتاج   194251133713
# 2   425787938                  مسكرا نارس كليماكس ميني NARS   607845270102
# 3  2109719584  نارس كريم أساس طبيعي طويل الأمد-فانواتو-30مل   607845066149
# 4   601007399    نارس كريم أساس طبيعي طويل الأمد-أروبا-30مل   607845066170
#
#   سعر المنتج السعر المخفض
# 0     155.25
# 1     155.25
# 2       89.7
# 3        253          167
# 4        253          167

# %%
df.rename(columns={'أسم المنتج': 'name', 'رمز المنتج sku': 'sku', 'سعر المنتج': 'price', 'السعر المخفض': 'price_after_discount'}, inplace=True)
df.head()
# Out:
#           No.                                          name           sku  \
# 0  1160462380        نارس أحمر شفاه أفتر جلو شاين - اورقازم  194251133683
# 1  1800282403         نارس أحمر شفاه أفتر جلو شاين - فولتاج  194251133713
# 2   425787938                  مسكرا نارس كليماكس ميني NARS  607845270102
# 3  2109719584  نارس كريم أساس طبيعي طويل الأمد-فانواتو-30مل  607845066149
# 4   601007399    نارس كريم أساس طبيعي طويل الأمد-أروبا-30مل  607845066170
#
#     price price_after_discount
# 0  155.25
# 1  155.25
# 2    89.7
# 3     253                  167
# 4     253                  167

# %%
skus = list(df['sku'])
skus_golden_scent = skus
skus_asrarco = skus
skus_sara_store = skus
skus_cvaley = skus
skus[:5]
# Out:
# [194251133683, 194251133713, 607845270102, 607845066149, 607845066170]

# %%
def cvaley_scraper(min_idx = 0, max_idx = 13517, function_num = 0):
    # cvaley
    globals()[f'prices_cvaley_{function_num}'] = []
    for sku_cvaley in skus_cvaley[min_idx:max_idx]:
        # Define the API endpoint and parameters
        url = "https://api.salla.dev/store/v1/products"
        params = {
            "source": "search",
            "source_value": f"{sku_cvaley}"  # SKU to search for
        }

        # Define the headers
        headers = {
            "accept": "application/json, text/plain, */*",
            "accept-language": "ar",
            "cache-control": "no-cache",
            "currency": "SAR",
            "priority": "u=1, i",
            "s-app-os": "browser",
            "s-app-version": "v2.0.0",
            "s-ray": "50",
            "s-source": "twilight",
            "s-user-id": "4hurTQNcwHYyhiSEUdPdfuIq1raYDyCVxi41XU2P",
            "sec-ch-ua": "\"Chromium\";v=\"131\", \"Not_A Brand\";v=\"24\"",
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": "\"Windows\"",
            "sec-fetch-dest": "empty",
            "sec-fetch-mode": "cors",
            "sec-fetch-site": "cross-site",
            "store-identifier": "194719587",
            "x-requested-with": "XMLHttpRequest"
        }

        # Send the GET request
        response = requests.get(url, headers=headers, params=params)

        # Check the response status
        if response.status_code == 200:
            data = response.json()

            # Check if we got the product data
            product_data = data.get('data', [])
            if product_data:
                globals()[f'price_cvaley_{function_num}'] = float(product_data[0].get('price', 'price_cvaley not found'))
                print(f"SAR price_cvaley_{function_num}: {globals()[f'price_cvaley_{function_num}']}")
                globals()[f'prices_cvaley_{function_num}'].append(globals()[f'price_cvaley_{function_num}'])
            else:
                print(f"price_cvaley_{function_num} information not found in the response.")
                globals()[f'prices_cvaley_{function_num}'].append(None)
        elif response.status_code == 429:
            print('Status code 429')
            globals()[f'prices_cvaley_{function_num}'].append(None)
            random_delay(3000,5000)
        else:
            print(f"Request failed in cvaley with status code: {response.status_code}")
            globals()[f'prices_cvaley_{function_num}'].append(None)

# %%
def sara_store_scraper(min_idx = 0, max_idx = 13517, function_num = 0):
    # sara store
    globals()[f'prices_sara_store_{function_num}'] = []
    for sku_sara_store in skus_sara_store[min_idx:max_idx]:
    # Define the API endpoint and parameters
        url = "https://api.salla.dev/store/v1/products"
        params = {
            "source": "search",
            "source_value": f"{sku_sara_store}"  # sku_sara_store to search for
        }

        # Define the headers
        headers = {
            "accept": "application/json, text/plain, */*",
            "accept-language": "ar",
            "cache-control": "no-cache",
            "currency": "SAR",
            "priority": "u=1, i",
            "s-app-os": "browser",
            "s-app-version": "v2.0.0",
            "s-ray": "100",
            "s-source": "twilight",
            "s-user-id": "PfoiUyhKBvCJgJoCVx9Rqt9kED7GAdQmNwFOdI1T",
            "sec-ch-ua": "\"Chromium\";v=\"131\", \"Not_A Brand\";v=\"24\"",
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": "\"Windows\"",
            "sec-fetch-dest": "empty",
            "sec-fetch-mode": "cors",
            "sec-fetch-site": "cross-site",
            "store-identifier": "1165709693",
            "x-requested-with": "XMLHttpRequest"
        }

        # Send the GET request
        response = requests.get(url, headers=headers, params=params)

        # Check the response status
        if response.status_code == 200:
            data = response.json()

            # Check if we got the product data
            product_data = data.get('data', [])
            if product_data:
                globals()[f'price_sara_store_{function_num}'] = float(product_data[0].get('price', 'Price_sara_store not found'))
                print(f"SAR Price_sara_store_{function_num}: {globals()[f'price_sara_store_{function_num}']}")
                globals()[f'prices_sara_store_{function_num}'].append(globals()[f'price_sara_store_{function_num}'])
            else:
                print(f"Price_sara_store_{function_num} information not found in the response.")
                globals()[f'prices_sara_store_{function_num}'].append(None)
        elif response.status_code == 429:
            print('Status code 429')
            globals()[f'prices_cvaley_{function_num}'].append(None)
            random_delay(3000,5000)
        else:
            print(f"Request failed in sara store with status code: {response.status_code}")
            globals()[f'prices_sara_store_{function_num}'].append(None)

# %%
def asrarco_scraper(min_idx = 0, max_idx = 13517, function_num = 0):
    # asrarco
    globals()[f'prices_asrarco_{function_num}'] = []
    for sku_asrarco in skus_asrarco[min_idx:max_idx]:
        # Define the API endpoint and parameters
        url = "https://api.salla.dev/store/v1/products"
        params = {
            "source": "search",
            "source_value": f"{sku_asrarco}"  # sku_asrarco to search for
        }

        # Define the headers
        headers = {
            "accept": "application/json, text/plain, */*",
            "accept-language": "ar",
            "cache-control": "no-cache",
            "currency": "SAR",
            "priority": "u=1, i",
            "s-app-os": "browser",
            "s-app-version": "v2.0.0",
            "s-ray": "100",
            "s-source": "twilight",
            "s-user-id": "JIqb2koIM7s5UaYXAveKMWNPvWrqDs9xopy8lcFD",
            "sec-ch-ua": "\"Chromium\";v=\"131\", \"Not_A Brand\";v=\"24\"",
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": "\"Windows\"",
            "sec-fetch-dest": "empty",
            "sec-fetch-mode": "cors",
            "sec-fetch-site": "cross-site",
            "store-identifier": "417733722",
            "x-requested-with": "XMLHttpRequest"
        }

        # Send the GET request
        response = requests.get(url, headers=headers, params=params)

        # Check the response status
        if response.status_code == 200:
            data = response.json()

            # Check if we got the product data
            product_data = data.get('data', [])
            if product_data:
                globals()[f'price_asrarco_{function_num}'] = float(product_data[0].get('price', 'price not found'))
                print(f"SAR price_asrarco_{function_num}: {globals()[f'price_asrarco_{function_num}']}")
                globals()[f'prices_asrarco_{function_num}'].append(globals()[f'price_asrarco_{function_num}'])
            else:
                print(f"price_asrarco_{function_num} information not found in the response.")
                globals()[f'prices_asrarco_{function_num}'].append(None)
        elif response.status_code == 429:
            print('Status code 429')
            globals()[f'prices_cvaley_{function_num}'].append(None)
            random_delay(3000,5000)
        else:
            print(f"Request failed in asrarco with status code: {response.status_code}")
            globals()[f'prices_asrarco_{function_num}'].append(None)

# %%
def goldenscent_scraper(min_idx = 0, max_idx = 13517, function_num = 0):
    # goldenscent
    globals()[f'prices_golden_scent_{function_num}'] = []
    for sku_golden_scent in skus_golden_scent[min_idx:max_idx]:
        # API endpoint
        url = "https://s7prcq95b5-dsn.algolia.net/1/indexes/magento_ar_sa_products/query"

        # Headers
        headers = {
            "accept": "application/json",
            "accept-language": "en-US,en;q=0.9",
            "content-type": "application/json",
            "sec-ch-ua": '"Chromium";v="131", "Not_A Brand";v="24"',
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": '"Windows"',
            "sec-fetch-dest": "empty",
            "sec-fetch-mode": "cors",
            "sec-fetch-site": "cross-site",
            "referrer": "https://www.goldenscent.com/",
            "referrerPolicy": "strict-origin-when-cross-origin"
        }

        # Query parameters included in the URL
        params = {
            "x-algolia-agent": "Algolia for JavaScript (3.35.1); Browser",
            "x-algolia-application-id": "S7PRCQ95B5",
            "x-algolia-api-key": "bed7f0e03f982f3ff679b25691f03895"
        }
        # Request payload for the new sku_golden_scent
        data = {
            "params": f"query={sku_golden_scent}&analytics=true&clickAnalytics=true&page=0&hitsPerPage=5&analyticsTags=%5B%22web%22%2C%22{sku_golden_scent}%22%5D"
        }

        # Send the POST request
        response = requests.post(url, headers=headers, params=params, data=json.dumps(data))
        if response.status_code == 200:
            try:
                # Extract and print the SAR original price
                globals()[f'price_golden_scent_{function_num}'] = float(response.json()['hits'][0]['price']['SAR']['default'])
                print(f"SAR Price golden_scent_{function_num}: {globals()[f'price_golden_scent_{function_num}']}")
                globals()[f'prices_golden_scent_{function_num}'].append(globals()[f'price_golden_scent_{function_num}'])
            except (KeyError, IndexError):
                print(f"price_golden_scent_{function_num} information not found in the response.")
                globals()[f'prices_golden_scent_{function_num}'].append(None)
        elif response.status_code == 429:
            print('Status code 429')
            globals()[f'prices_cvaley_{function_num}'].append(None)
            random_delay(3000,5000)
        else:
            print(f"Request failed in golden scent with status code: {response.status_code}")
            globals()[f'prices_golden_scent_{function_num}'].append(None)

# %%
prices_golden_scent = []
prices_cvaley = []
prices_asrarco = []
prices_sara_store = []

threads = [
    threading.Thread(target=goldenscent_scraper, args=(0, 6758, 1)),
    threading.Thread(target=goldenscent_scraper, args=(6758, 13517, 2)),

    threading.Thread(target=asrarco_scraper, args=(0, 6758, 1)),
    threading.Thread(target=asrarco_scraper, args=(6758, 13517, 2)),

    threading.Thread(target=sara_store_scraper, args=(0, 6758, 1)),
    threading.Thread(target=sara_store_scraper, args=(6758, 13517, 2)),

    threading.Thread(target=cvaley_scraper, args=(0, 6758, 1)),
    threading.Thread(target=cvaley_scraper, args=(6758, 13517, 2))
]

# Start threads
for thread in threads:
    thread.start()

# Wait for all threads to complete
for thread in threads:
    thread.join()

prices_golden_scent[0:6758] = prices_golden_scent_1
prices_golden_scent[6758:13517] = prices_golden_scent_2

prices_asrarco[0:6758] = prices_asrarco_1
prices_asrarco[6758:13517] = prices_asrarco_2

prices_sara_store[0:6758] = prices_sara_store_1
prices_sara_store[6758:13517] = prices_sara_store_2

prices_cvaley[0:6758] = prices_cvaley_1
prices_cvaley[6758:13517] = prices_cvaley_2
# Out:
# Streaming output truncated to the last 5000 lines.
# SAR price_asrarco_1: 33.5
# SAR price_asrarco_2: 84.85
# price_cvaley_2 information not found in the response.
# Price_sara_store_1 information not found in the response.
# Price_sara_store_2 information not found in the response.
# price_cvaley_1 information not found in the response.
# SAR price_asrarco_1: 31.13
# price_cvaley_2 information not found in the response.
# SAR price_asrarco_2: 14.5
# Price_sara_store_2 information not found in the response.
# Price_sara_store_1 information not found in the response.
# price_cvaley_1 information not found in the response.
# SAR price_asrarco_1: 31.13
# Price_sara_store_1 information not found in the response.
# price_cvaley_1 information not found in the response.
# price_cvaley_2 information not found in the response.
# price_asrarco_2 information not found in the response.
# Price_sara_store_2 information not found in the response.
# SAR price_asrarco_1: 130.01
# ...

# %%
df['golden_scent_price'] = prices_golden_scent
df['cvaley_price'] = prices_cvaley
df['asrarco_price'] = prices_asrarco
df['sara_store_price'] = prices_sara_store

df.head()
# Out:
#           No.                                          name           sku  \
# 0  1160462380        نارس أحمر شفاه أفتر جلو شاين - اورقازم  194251133683
# 1  1800282403         نارس أحمر شفاه أفتر جلو شاين - فولتاج  194251133713
# 2   425787938                  مسكرا نارس كليماكس ميني NARS  607845270102
# 3  2109719584  نارس كريم أساس طبيعي طويل الأمد-فانواتو-30مل  607845066149
# 4   601007399    نارس كريم أساس طبيعي طويل الأمد-أروبا-30مل  607845066170
#
#     price price_after_discount  golden_scent_price  cvaley_price  \
# 0  155.25                                      NaN           NaN
# 1  155.25                                      NaN           NaN
# 2    89.7                                      NaN           NaN
# 3     253                  167                 NaN           NaN
# 4     253                  167                 NaN           NaN
#
#    asrarco_price  sara_store_price
# 0            NaN            155.25
# 1            NaN            155.25
# ...

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['price_after_discount'] = pd.to_numeric(df['price_after_discount'], errors='coerce')
df.head()
# Out:
#           No.                                          name           sku  \
# 0  1160462380        نارس أحمر شفاه أفتر جلو شاين - اورقازم  194251133683
# 1  1800282403         نارس أحمر شفاه أفتر جلو شاين - فولتاج  194251133713
# 2   425787938                  مسكرا نارس كليماكس ميني NARS  607845270102
# 3  2109719584  نارس كريم أساس طبيعي طويل الأمد-فانواتو-30مل  607845066149
# 4   601007399    نارس كريم أساس طبيعي طويل الأمد-أروبا-30مل  607845066170
#
#     price  price_after_discount  golden_scent_price  cvaley_price  \
# 0  155.25                   NaN                 NaN           NaN
# 1  155.25                   NaN                 NaN           NaN
# 2   89.70                   NaN                 NaN           NaN
# 3  253.00                 167.0                 NaN           NaN
# 4  253.00                 167.0                 NaN           NaN
#
#    asrarco_price  sara_store_price
# 0            NaN            155.25
# 1            NaN            155.25
# ...

# %%
# Calculate the new columns
df['price_vat'] = (df['price'] + df['price'] * 0.15).round(2)
df['price_after_discount_vat'] = (df['price_after_discount'] + df['price_after_discount'] * 0.15).round(2)

# Reorder columns
cols = list(df.columns)
cols.insert(cols.index('price') + 1, cols.pop(cols.index('price_vat')))
cols.insert(cols.index('price_after_discount') + 1, cols.pop(cols.index('price_after_discount_vat')))
df = df[cols]

df.head()
# Out:
#           No.                                          name           sku  \
# 0  1160462380        نارس أحمر شفاه أفتر جلو شاين - اورقازم  194251133683
# 1  1800282403         نارس أحمر شفاه أفتر جلو شاين - فولتاج  194251133713
# 2   425787938                  مسكرا نارس كليماكس ميني NARS  607845270102
# 3  2109719584  نارس كريم أساس طبيعي طويل الأمد-فانواتو-30مل  607845066149
# 4   601007399    نارس كريم أساس طبيعي طويل الأمد-أروبا-30مل  607845066170
#
#     price  price_vat  price_after_discount  price_after_discount_vat  \
# 0  155.25     178.54                   NaN                       NaN
# 1  155.25     178.54                   NaN                       NaN
# 2   89.70     103.16                   NaN                       NaN
# 3  253.00     290.95                 167.0                    192.05
# 4  253.00     290.95                 167.0                    192.05
#
#    golden_scent_price  cvaley_price  asrarco_price  sara_store_price
# ...

# %%
df.fillna("", inplace=True)
df.head()
# Out:
# <ipython-input-15-9a040e6a4327>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("", inplace=True)
#           No.                                          name           sku  \
# 0  1160462380        نارس أحمر شفاه أفتر جلو شاين - اورقازم  194251133683
# 1  1800282403         نارس أحمر شفاه أفتر جلو شاين - فولتاج  194251133713
# 2   425787938                  مسكرا نارس كليماكس ميني NARS  607845270102
# 3  2109719584  نارس كريم أساس طبيعي طويل الأمد-فانواتو-30مل  607845066149
# 4   601007399    نارس كريم أساس طبيعي طويل الأمد-أروبا-30مل  607845066170
#
#     price price_vat price_after_discount price_after_discount_vat  \
# 0  155.25    178.54
# 1  155.25    178.54
# 2    89.7    103.16
# 3   253.0    290.95                167.0                   192.05
# ...

# %%
cairo_tz = pytz.timezone('Africa/Cairo')
current_time = datetime.now(cairo_tz).strftime('%Y-%m-%d %H:%M:%S')

# Add the new column with the current time
df['updated'] = current_time

# %%
df.head()
# Out:
#           No.                                          name           sku  \
# 0  1160462380        نارس أحمر شفاه أفتر جلو شاين - اورقازم  194251133683
# 1  1800282403         نارس أحمر شفاه أفتر جلو شاين - فولتاج  194251133713
# 2   425787938                  مسكرا نارس كليماكس ميني NARS  607845270102
# 3  2109719584  نارس كريم أساس طبيعي طويل الأمد-فانواتو-30مل  607845066149
# 4   601007399    نارس كريم أساس طبيعي طويل الأمد-أروبا-30مل  607845066170
#
#     price price_vat price_after_discount price_after_discount_vat  \
# 0  155.25    178.54
# 1  155.25    178.54
# 2    89.7    103.16
# 3   253.0    290.95                167.0                   192.05
# 4   253.0    290.95                167.0                   192.05
#
#   golden_scent_price cvaley_price asrarco_price sara_store_price  \
# 0                                                         155.25
# 1                                                         155.25
# ...

# %%
try:
    results_sheet = spreadsheet.worksheet("results")
except gspread.exceptions.WorksheetNotFound:
    results_sheet = spreadsheet.add_worksheet(title="results", rows="100", cols="20")

# Convert the DataFrame to a list of lists (including header)
data_to_upload = [df.columns.tolist()] + df.values.tolist()

# Clear the sheet and update with the new data
results_sheet.clear()
results_sheet.update('A1', data_to_upload)

print("Data saved successfully to the 'results' sheet.")
# Out:
# <ipython-input-18-64d357b3ac27>:11: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   results_sheet.update('A1', data_to_upload)
# Data saved successfully to the 'results' sheet.
